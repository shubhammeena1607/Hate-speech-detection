# %%
#import library
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("D:\labeled_data.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\dell\AppData\Local\Temp\ipykernel_1912\3204176722.py:1: SyntaxWarning: invalid escape sequence '\l'
#   dataset = pd.read_csv("D:\labeled_data.csv")

# %%
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
# [24783 rows x 7 columns]

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
dataset.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %%
#creat a new feature
dataset["label"] = dataset["class"].map({0:"hate speech",
                                         1:"offensive",
                                         2:"no hate or offensive"})

# %%
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet                 label
# 0      !!! RT @mayasolovely: As a woman you shouldn't...  no hate or offensive
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...             offensive
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...             offensive
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...             offensive
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...             offensive
# ...                                                  ...                   ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...             offensive
# 24779  you've gone and broke the wrong heart baby, an...  no hate or offensive
# 24780  young buck wanna eat!!.. dat nigguh like I ain...             offensive
# 24781              youu got wild bitches tellin you lies             offensive
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...  no hate or offensive
#
# [24783 rows x 8 columns]

# %%
data = dataset[["tweet","label"]]

# %%
data
# Out:
#                                                    tweet                 label
# 0      !!! RT @mayasolovely: As a woman you shouldn't...  no hate or offensive
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...             offensive
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...             offensive
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...             offensive
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...             offensive
# ...                                                  ...                   ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...             offensive
# 24779  you've gone and broke the wrong heart baby, an...  no hate or offensive
# 24780  young buck wanna eat!!.. dat nigguh like I ain...             offensive
# 24781              youu got wild bitches tellin you lies             offensive
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...  no hate or offensive
#
# [24783 rows x 2 columns]

# %%
import re
import nltk
import string

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#import stop word
from nltk.corpus import stopwords
stopwords = set(stopwords.words("english"))

# %%
#import stemming 
stemmer = nltk.SnowballStemmer("english")

# %%
# data cleaning 
def clean_data(text):
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    #stop words removal
    text = [word for word in text.split(' ')if word not in stopwords]
    text = " ".join(text)
    # stemming the text 
    text = [stemmer.stem(word)for word in text.split(' ')]
    text = " ".join(text)
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\dell\AppData\Local\Temp\ipykernel_1912\2980861018.py:3: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]', '', text)
# C:\Users\dell\AppData\Local\Temp\ipykernel_1912\2980861018.py:7: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub('\w*\d\w*', '', text)

# %%
data["tweet"] = data["tweet"].apply(clean_data)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_1912\1832165696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["tweet"] = data["tweet"].apply(clean_data)

# %%
data
# Out:
#                                                    tweet                 label
# 0       rt mayasolov as woman shouldnt complain clean...  no hate or offensive
# 1       rt  boy dat coldtyga dwn bad cuffin dat hoe  ...             offensive
# 2       rt urkindofbrand dawg rt  you ever fuck bitch...             offensive
# 3                 rt cganderson vivabas look like tranni             offensive
# 4       rt shenikarobert the shit hear might true mig...             offensive
# ...                                                  ...                   ...
# 24778  yous muthafin lie   coreyemanuel right his tl ...             offensive
# 24779  youv gone broke wrong heart babi drove redneck...  no hate or offensive
# 24780  young buck wanna eat dat nigguh like i aint fu...             offensive
# 24781                     youu got wild bitch tellin lie             offensive
# 24782  ruffl  ntac eileen dahlia  beauti color combin...  no hate or offensive
#
# [24783 rows x 2 columns]

# %%
X = np.array(data["tweet"])
Y = np.array(data["label"])

# %%
X
# Out:
# array([' rt mayasolov as woman shouldnt complain clean hous amp man alway take trash',
#        ' rt  boy dat coldtyga dwn bad cuffin dat hoe  place',
#        ' rt urkindofbrand dawg rt  you ever fuck bitch start cri you confus shit',
#        ..., 'young buck wanna eat dat nigguh like i aint fuckin dis',
#        'youu got wild bitch tellin lie',
#        'ruffl  ntac eileen dahlia  beauti color combin pink orang yellow amp white a coll '],
#       dtype=object)

# %%
Y
# Out:
# array(['no hate or offensive', 'offensive', 'offensive', ..., 'offensive',
#        'offensive', 'no hate or offensive'], dtype=object)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
cv = CountVectorizer()
X = cv.fit_transform(X)

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 207792 stored elements and shape (24783, 26233)>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.33, random_state=42)

# %%
 X_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 68550 stored elements and shape (8179, 26233)>

# %%
# Building out ML Model
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = dt.predict(X_test)

# %%
# Confusion matrix and accuracy
from sklearn.metrics import confusion_matrix

# Assuming Y_test and Y_pred are defined
cm = confusion_matrix(Y_test, Y_pred)
print(cm)
# Out:
# [[ 154   34  277]
#  [  30 1117  232]
#  [ 231  223 5881]]

# %%
import seaborn as sns
import matplotlib.pyplot as ply
# %matplotlib inline

# %%
# Assuming cm is your confusion matrix
sns.heatmap(cm, annot=True, fmt=".1f", cmap="YlGnBu")
ply.show()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, Y_pred)
# Out:
# 0.8744345274483433

# %%
sample = "Let's unite and kill all the people who are protesting against the government"
sample = clean_data(sample)

# %%
sample
# Out:
# 'let unit kill peopl protest govern'

# %%
data1 = cv.transform([sample]).toarray()

# %%
data1
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
dt.predict(data1)
# Out:
# array(['hate speech'], dtype=object)
